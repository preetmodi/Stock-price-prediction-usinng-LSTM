# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\preet\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast==0.2.2 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (0.2.2)
# Requirement already satisfied: astor>=0.6.0 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (0.8.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: tensorflow-estimator<2.2.0,>=2.1.0rc0 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (1.12.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (1.28.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (0.32.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (1.18.2)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (1.0.8)
# Requirement already satisfied: protobuf>=3.8.0 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: tensorboard<2.2.0,>=2.1.0 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (1.4.1)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\preet\anaconda3\lib\site-packages (from tensorflow) (0.9.0)
# Requirement already satisfied: h5py in c:\users\preet\anaconda3\lib\site-packages (from keras-applications>=1.0.8->tensorflow) (2.8.0)
# Requirement already satisfied: setuptools in c:\users\preet\anaconda3\lib\site-packages (from protobuf>=3.8.0->tensorflow) (46.1.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\preet\anaconda3\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (1.13.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\preet\anaconda3\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (3.2.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\preet\anaconda3\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (0.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\preet\anaconda3\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (0.14.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\preet\anaconda3\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (2.21.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\preet\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (4.0.0)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in c:\users\preet\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\preet\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\preet\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow) (1.3.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\preet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\preet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\preet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\preet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (2.8)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\preet\anaconda3\lib\site-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\preet\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow) (3.1.0)

# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading https://files.pythonhosted.org/packages/22/f1/a02eea03628865c3d4c29849cda8c8a73f43358048aee47d79dfbfa6c6c3/pandas_datareader-0.9.0-py3-none-any.whl (107kB)
# Requirement already satisfied: pandas>=0.23 in c:\users\preet\anaconda3\lib\site-packages (from pandas_datareader) (0.23.4)
# Requirement already satisfied: lxml in c:\users\preet\anaconda3\lib\site-packages (from pandas_datareader) (4.2.5)
# Requirement already satisfied: requests>=2.19.0 in c:\users\preet\anaconda3\lib\site-packages (from pandas_datareader) (2.21.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\preet\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.7.5)
# Requirement already satisfied: pytz>=2011k in c:\users\preet\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2018.7)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\preet\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.18.2)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\preet\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\preet\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\preet\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\preet\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2020.4.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\preet\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas>=0.23->pandas_datareader) (1.12.0)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.9.0

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\preet\anaconda3\lib\site-packages (0.20.1)
# Requirement already satisfied: numpy>=1.8.2 in c:\users\preet\anaconda3\lib\site-packages (from scikit-learn) (1.18.2)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\preet\anaconda3\lib\site-packages (from scikit-learn) (1.4.1)

# %%
import sklearn

# %%
import pandas as pd
import numpy as np

from pandas_datareader.data import DataReader
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
# from tensorflow.keras.Layers import Dense, LSTM

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("Tesla.csv")
data['Date'] = pd.to_datetime(data.Date)
data = data.set_index(['Date'])
data
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2010-06-29   19.000000   25.000000   17.540001   23.889999  18766300
# 2010-06-30   25.790001   30.420000   23.299999   23.830000  17187100
# 2010-07-01   25.000000   25.920000   20.270000   21.959999   8218800
# 2010-07-02   23.000000   23.100000   18.709999   19.200001   5139800
# 2010-07-06   20.000000   20.000000   15.830000   16.110001   6866900
# 2010-07-07   16.400000   16.629999   14.980000   15.800000   6921700
# 2010-07-08   16.139999   17.520000   15.570000   17.459999   7711400
# 2010-07-09   17.580000   17.900000   16.549999   17.400000   4050600
# 2010-07-12   17.950001   18.070000   17.000000   17.049999   2202500
# 2010-07-13   17.389999   18.639999   16.900000   18.139999   2680100
# 2010-07-14   17.940001   20.150000   17.760000   19.840000   4195200
# 2010-07-15   19.940001   21.500000   19.000000   19.889999   3739800
# 2010-07-16   20.700001   21.299999   20.049999   20.639999   2621300
# 2010-07-19   21.370001   22.250000   20.920000   21.910000   2486500
# 2010-07-20   21.850000   21.850000   20.049999   20.299999   1825300
# 2010-07-21   20.660000   20.900000   19.500000   20.219999   1252500
# 2010-07-22   20.500000   21.250000   20.370001   21.000000    957800
# 2010-07-23   21.190001   21.559999   21.059999   21.290001    653600
# 2010-07-26   21.500000   21.500000   20.299999   20.950001    922200
# 2010-07-27   20.910000   21.180000   20.260000   20.549999    619700
# 2010-07-28   20.549999   20.900000   20.510000   20.719999    467200
# 2010-07-29   20.770000   20.879999   20.000000   20.350000    616000
# 2010-07-30   20.200001   20.440001   19.549999   19.940001    426900
# 2010-08-02   20.500000   20.969999   20.330000   20.920000    718100
# 2010-08-03   21.000000   21.950001   20.820000   21.950001   1230500
# 2010-08-04   21.950001   22.180000   20.850000   21.260000    913000
# 2010-08-05   21.540001   21.549999   20.049999   20.450001    796200
# 2010-08-06   20.100000   20.160000   19.520000   19.590000    741900
# 2010-08-09   19.900000   19.980000   19.450001   19.600000    812700
# 2017-02-22  273.510010
# 2017-02-23  255.990005
# 2017-02-24  257.000000
# 2017-02-27  246.229996
# 2017-02-28  249.990005
# 2017-03-01  250.020004
# 2017-03-02  250.479996
# 2017-03-03  251.570007
# 2017-03-06  251.210007
# 2017-03-07  248.589996
# 2017-03-08  246.869995
# 2017-03-09  244.899994
# 2017-03-10  243.690002
# 2017-03-13  246.169998
# 2017-03-14  258.000000
# 2017-03-15  255.729996
# 2017-03-16  262.049988
# 2017-03-17  261.500000
#
# [1692 rows x 6 columns]

# %%
# end = datetime.now()
# start = datetime(end.year-5, end.month, end.day)
# data = DataReader(
#             'AAPL',
#             'yahoo',
#             start=start,
#             end=end)
# data

# %%
# data['Date'] = pd.to_datetime(data.index, format='%y-%m-%d', errors='ignore')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1692 entries, 2010-06-29 to 2017-03-17
# Data columns (total 6 columns):
# Open         1692 non-null float64
# High         1692 non-null float64
# Low          1692 non-null float64
# Close        1692 non-null float64
# Volume       1692 non-null int64
# Adj Close    1692 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 92.5 KB

# %%
plt.figure(figsize=(16,8))
plt.plot(data['Close'], label='Close Price history')

# %%
dataset = pd.DataFrame(index=(range(0,len(data))),columns=['Date','Close'])
data = data.sort_index(ascending=True, axis=0)
dataset['Date'] = data.index
dataset = dataset.set_index(['Date'])
dataset['Close'] = data['Close']
# data['Date']

dataset
# Out:
#                  Close
# Date
# 2010-06-29   23.889999
# 2010-06-30   23.830000
# 2010-07-01   21.959999
# 2010-07-02   19.200001
# 2010-07-06   16.110001
# 2010-07-07   15.800000
# 2010-07-08   17.459999
# 2010-07-09   17.400000
# 2010-07-12   17.049999
# 2010-07-13   18.139999
# 2010-07-14   19.840000
# 2010-07-15   19.889999
# 2010-07-16   20.639999
# 2010-07-19   21.910000
# 2010-07-20   20.299999
# 2010-07-21   20.219999
# 2010-07-22   21.000000
# 2010-07-23   21.290001
# 2010-07-26   20.950001
# 2010-07-27   20.549999
# 2010-07-28   20.719999
# 2010-07-29   20.350000
# 2010-07-30   19.940001
# 2010-08-02   20.920000
# 2010-08-03   21.950001
# 2010-08-04   21.260000
# 2010-08-05   20.450001
# 2010-08-06   19.590000
# 2010-08-09   19.600000
# 2010-08-10   19.030001
# ...                ...
# 2017-02-03  251.330002
# 2017-02-06  257.769989
# 2017-02-07  257.480011
# 2017-02-08  262.079987
# 2017-02-09  269.200012
# 2017-02-10  269.230011
# 2017-02-13  280.600006
# 2017-02-14  280.980011
# 2017-02-15  279.760010
# 2017-02-16  268.950012
# 2017-02-17  272.230011
# 2017-02-21  277.390015
# 2017-02-22  273.510010
# 2017-02-23  255.990005
# 2017-02-24  257.000000
# 2017-02-27  246.229996
# 2017-02-28  249.990005
# 2017-03-01  250.020004
# 2017-03-02  250.479996
# 2017-03-03  251.570007
# 2017-03-06  251.210007
# 2017-03-07  248.589996
# 2017-03-08  246.869995
# 2017-03-09  244.899994
# 2017-03-10  243.690002
# 2017-03-13  246.169998
# 2017-03-14  258.000000
# 2017-03-15  255.729996
# 2017-03-16  262.049988
# 2017-03-17  261.500000
#
# [1692 rows x 1 columns]

# %%
split = int(len(dataset)*0.75)
X = dataset.values
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(X)
scaled_data
# Out:
# array([[0.02993635],
#        [0.02971433],
#        [0.02279455],
#        ...,
#        [0.88784039],
#        [0.91122698],
#        [0.9091918 ]])

# %%
train = scaled_data[:split,:]
valid = scaled_data[split:,:]
X_train = []
y_train = []
for i in range(60, len(train)):
    X_train.append(train[i-60:i, 0])
    y_train.append(train[i, 0])
    
X_train = np.array(X_train)
y_train = np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (1209, 60, 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(50))
model.add(Dense(1))

model.compile(optimizer= 'adam',
             loss = 'mean_squared_error')

# %%
model.fit(X_train, 
          y_train,
         epochs=2)
# Out:
# Train on 1209 samples
# Epoch 1/2
# 1209/1209 [==============================] - 4s 3ms/sample - loss: 0.0261
# Epoch 2/2
# 1209/1209 [==============================] - 2s 1ms/sample - loss: 0.0016

# %%
test_data  = scaled_data[split-60:,:]
X_test = []
for i in range(60,(len(test_data))):
    X_test.append(test_data[i-60:i,:])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
y_test = X[split:,:]
result = model.predict(X_test)
result = scaler.inverse_transform(result)

rmse = np.sqrt(np.mean((y_test-result)**2))
# Out:
# 13.853561384457404

# %%
test = pd.DataFrame(index=dataset[split:].index, columns=['Close'])
# test['Date'] = dataset[split:].index
test['Close'] = result
# test = test.set_index(['Date'])
test
# Out:
#                  Close
# Date
# 2015-07-15  259.059967
# 2015-07-16  258.855743
# 2015-07-17  258.740479
# 2015-07-20  258.904327
# 2015-07-21  259.466705
# 2015-07-22  259.904022
# 2015-07-23  260.277985
# 2015-07-24  260.561615
# 2015-07-27  260.717133
# 2015-07-28  260.446014
# 2015-07-29  260.183868
# 2015-07-30  259.894806
# 2015-07-31  259.682861
# 2015-08-03  259.521271
# 2015-08-04  259.246002
# 2015-08-05  259.065643
# 2015-08-06  259.054321
# 2015-08-07  258.538422
# 2015-08-10  257.586823
# 2015-08-11  256.290161
# 2015-08-12  254.671570
# 2015-08-13  252.890045
# 2015-08-14  251.162582
# 2015-08-17  249.552002
# 2015-08-18  248.406738
# 2015-08-19  247.797226
# 2015-08-20  247.467255
# 2015-08-21  247.012772
# 2015-08-24  246.170792
# 2015-08-25  244.732300
# ...                ...
# 2017-02-03  242.748215
# 2017-02-06  243.632614
# 2017-02-07  244.550049
# 2017-02-08  245.455093
# 2017-02-09  246.452789
# 2017-02-10  247.677368
# 2017-02-13  249.031494
# 2017-02-14  250.743042
# 2017-02-15  252.665741
# 2017-02-16  254.653412
# 2017-02-17  256.339081
# 2017-02-21  257.832153
# 2017-02-22  259.254425
# 2017-02-23  260.471558
# 2017-02-24  261.046722
# 2017-02-27  261.165924
# 2017-02-28  260.648651
# 2017-03-01  259.784363
# 2017-03-02  258.687836
# 2017-03-03  257.476135
# 2017-03-06  256.257050
# 2017-03-07  255.070679
# 2017-03-08  253.884918
# 2017-03-09  252.697708
# 2017-03-10  251.496231
# 2017-03-13  250.290695
# 2017-03-14  249.186523
# 2017-03-15  248.507736
# 2017-03-16  248.102005
# 2017-03-17  248.090790
#
# [423 rows x 1 columns]

# %%
plt.figure(figsize=(16,5))
plt.plot(dataset[:split], label='Training Data', color='blue')
plt.plot(dataset[split:], label='Test Data', color='blue')
plt.plot(test['Close'], label='Predicted Values', color='red')
plt.legend()
print("RMS error for this dataset is: ", rmse)
print()
print("Below shown is the graph suggesting the predicted values vs Actual values of the closing price of Tesla stock for the respective dates")
# Out:
# RMS error for this dataset is:  13.853561384457404
#
# Below shown is the graph suggesting the predicted values vs Actual values of the closing price of Tesla stock for the respective dates
